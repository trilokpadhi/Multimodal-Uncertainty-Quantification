# %%
import json 

path = '/home/ubuntu/Multimodal-Uncertainty-Quantification/datasets_/VQA-E_train_set.json'
with open(path, 'r') as f:
    data = json.load(f)

# %%
data
# Out:
# [{'answer_type': 'other',
#   'explanation': ['Closeup of bins of food that include broccoli and bread.',
#    0.6791202865162379],
#   'question': 'What is the green stuff?',
#   'multiple_choice_answer': 'broccoli',
#   'answers': ['broccoli',
#    'broccoli',
#    'broccoli',
#    'broccoli',
#    'broccoli',
#    'broccoli',
#    'broccoli',
#    'broccoli',
#    'broccoli',
#    'broccoli'],
#   'question_type': 'what is the',
#   'img_id': 9},
#  {'answer_type': 'other',
#   'explanation': ['Two giraffes standing in a tree filled area.',
#    0.780528326212856],
#   'question': 'What is in front of the giraffes?',
#   'multiple_choice_answer': 'tree',
#   'answers': ['tree',
#    'tree',
#    'tree',
#    'tree',
#    'tree',
#    'tree',
#    'tree',
#    'tree',
#    'trees',
#    'trees'],
#   'question_type': 'what is',
#   'img_id': 25},
#  {'answer_type': 'other',
#   'explanation': ['A giraffe eating food from the top of the tree.',
#    0.6914453666302058],
# ...
