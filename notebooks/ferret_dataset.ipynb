# %%
import pandas as pd

path = '/home/ubuntu/Multimodal-Uncertainty-Quantification/datasets/Ferret-Bench/data/test-00000-of-00001.parquet'
# read parquet file
df = pd.read_parquet(path)

# %%
print('Question', df.loc[0]['question'])
print('Answer', df.loc[0]['gpt_answer'])
# Out:
# Question The man [0.201, 0.002, 0.940, 0.758] is performing a trick on a skateboard [0.012, 0.746, 0.664, 0.886]. He appears to be in mid-air, indicating that he is probably performing a jump or some sort of aerial trick.
# Answer The man [0.201, 0.002, 0.940, 0.758] is performing a trick on a skateboard [0.012, 0.746, 0.664, 0.886]. He appears to be in mid-air, indicating that he is probably performing a jump or some sort of aerial trick.

# %%
df.iloc[10]['image']
# Out:
# {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xdb\x00C\x00\x01\x01\x01\x01\x01\x01\x01\x01\x01\x01\x01\x01\x01\x02\x02\x03\x02\x02\x02\x02\x02\x04\x03\x03\x02\x03\x05\x04\x05\x05\x05\x04\x04\x04\x05\x06\x07\x06\x05\x05\x07\x06\x04\x04\x06\t\x06\x07\x08\x08\x08\x08\x08\x05\x06\t\n\t\x08\n\x07\x08\x08\x08\xff\xdb\x00C\t\x03\x04\x01\x02\n\x00\x0b\xff\xc4\x00V\x10\x00\x01\x04\x01\x03\x04\x00\x04\x04\x03\x04\x06\x06\x06\x02\x13\x02\x01\x03\x04\x05\x06\x07\x11\x12\x00\x08\x13!\x14"1A\t\x15Qa#2q\x16$\x81\x913BR\xa1\xb1\xc1\n\x174C
# ...

# %%
df.columns
# Out:
# Index(['question_id', 'question', 'image', 'image_name', 'category', 'context',
#        'gpt_answer'],
#       dtype='object')
