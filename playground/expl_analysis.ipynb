# %%
# imports 
import sys
import os
import pickle

# %%
path = '/staging/users/tpadhi1/Multimodal-Uncertainty-Quantification/runs/llava_gqa_yes_gsam_grounding_random_100_test_24dec_/explanations_test/explanations_08909925.pkl'
with open(path, 'rb') as f:
    data = pickle.load(f)
# expl_files = os.listdir(path)

# %%
# data['response_1']
# if the key has 'response' in it, then it is the response of the model, so print it 

# for i, file in enumerate(expl_files):
#     if i >= 10:
#         break
#     with open(path + file, 'rb') as f:
#         data = pickle.load(f)
#         for key in data.keys():
#             if 'response' in key:
#                 print('response:', data[key]['decoded_outputs'])
#             else:
#                 print('its not a response')
                
# data.keys()
for key in data.keys():
    if 'response' in key:
        print('response:', data[key]['decoded_outputs'])
    else:
        print('its not a response')
# Out:
# its not a response
# its not a response
# its not a response
# its not a response
# its not a response
# its not a response
# its not a response
# response: Yes, the brown trees look leafy.
# response: Yes, the tree tops covered with snow have some green leaves.
# response: Answer: No, the brown trees do not look leafy.
# response: Yes, the trees are leafy.
# response: Answer: No, the brown trees look naked and leafless.
# response: Answer: No, the brown trees are bare.
# response: Answer: No, the brown trees are without leaves.
# response: Yes, the brown trees look leafy.
# response: Answer: No, the brown trees do not have any leaves.
# response: 1. Yes 2. No
# response: Answer: No, the brown trees have no leaves.
# response: Answer: No, the brown trees do not look leafy.
# response: Yes, the brown trees have leafy looking branches.
# response: Answer: No, the brown trees do not have any leaves.
# response: Yes, the brown trees look leafy.
# response:
# ...

# %%
data['response_1']
# Out:
# {'prompt': 'USER: Answer the questions, Here are few examples: \n         Question: What is the color of the object?\n        Answer: The color of the object is red.\n        Question: Is the color of the object red?\n        Answer: Yes, the color of the object is red.\n        Question: Do you see clocks in the image?\n        Answer: No, I do not see any clocks in the image.\n        \n        \n        Do the brown trees look leafy?\n        ',
#  'transition_scores': array([-1.5068601 , -0.01507861, -0.01155069, -7.0790396 , -3.8143644 ,
#         -0.15820333, -5.8039904 , -1.0105166 , -0.51607466, -2.3862622 ,
#         -1.1462902 , -1.6477247 , -0.25260803, -0.41791728, -0.04749535,
#                -inf,        -inf], dtype=float32),
#  'decoded_outputs': 'Yes, the tree tops covered with snow have some green leaves.'}
