# %%
import pickle

path = '/staging/users/tpadhi1/Multimodal-Uncertainty-Quantification/runs_slake/gemini_slake/explanations/explanations_0.pkl'

with open(path, 'rb') as f:
    explanations = pickle.load(f)

# %%
explanations
# Out:
# {'img_names': ['xmlab1/source.jpg'],
#  'locations': ['Abdomen'],
#  'answers': ['MRI'],
#  'modalities': ['MRI'],
#  'base_types': ['vqa'],
#  'answer_types': ['OPEN'],
#  'questions': ['What modality is used to take this image?'],
#  'qids': [0],
#  'content_types': ['Modality'],
#  'triples': [['vhead', '_', '_']],
#  'img_ids': [1],
#  'q_langs': ['en'],
#  'promptified_questions': ['Question: What modality is used to take this image?\n        Answer: The modality used to take this image is MRI.\n        Question: Question: Which part of the body does this image belong to?\n        Answer: This image belongs to the abdomen.\n        Question: What is the main organ in the image?\n        Answer: The main organ in the image is Lung and Spinal Cord.\n        \nQuestion: What modality is used to take this image?\n  \nAnswer:'],
#  'image_paths': ['/staging/users/tpadhi1/Multimodal-Uncertainty-Quantification/datasets_/Slake1.0/imgs/xmlab1/source.jpg'],
# ...
